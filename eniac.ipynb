# %% [markdown]
# <a href="https://colab.research.google.com/github/Dilek-D/Dilek-Goes-with-Panda-Coding-1/blob/main/eniac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
brands_df1=pd.read_csv("/content/brands (1).csv")
brands_df1
# Out:
#     short       long
# 0     8MO  8Mobility
# 1     ACM       Acme
# 2     ADN     Adonit
# 3     AII      Aiino
# 4     AKI     Akitio
# ..    ...        ...
# 182   XOO     Xoopar
# 183   XRI     X-Rite
# 184   XTO      Xtorm
# 185   ZAG   ZaggKeys
# 186   ZEP       Zepp
#
# [187 rows x 2 columns]

# %%
import pandas as pd
orderlines_df2=pd.read_csv("/content/orderlines.csv")
orderlines_df2
# Out:
#              id  id_order  product_id  product_quantity      sku unit_price  \
# 0       1119109    299539           0                 1  OTT0133      18.99
# 1       1119110    299540           0                 1  LGE0043     399.00
# 2       1119111    299541           0                 1  PAR0071     474.05
# 3       1119112    299542           0                 1  WDT0315      68.39
# 4       1119113    299543           0                 1  JBL0104      23.74
# ...         ...       ...         ...               ...      ...        ...
# 293978  1650199    527398           0                 1  JBL0122      42.99
# 293979  1650200    527399           0                 1  PAC0653     141.58
# 293980  1650201    527400           0                 2  APP0698       9.99
# 293981  1650202    527388           0                 1  BEZ0204      19.99
# 293982  1650203    527401           0                 1  APP0927      13.99
#
#                        date
# ...

# %%
import pandas as pd
orders_df3=pd.read_csv("/content/orders.csv")
orders_df3
# Out:
#         order_id         created_date  total_paid            state
# 0         241319  2017-01-02 13:35:40       44.99        Cancelled
# 1         241423  2017-11-06 13:10:02      136.15        Completed
# 2         242832  2017-12-31 17:40:03       15.76        Completed
# 3         243330  2017-02-16 10:59:38       84.98        Completed
# 4         243784  2017-11-24 13:35:19      157.86        Cancelled
# ...          ...                  ...         ...              ...
# 226904    527397  2018-03-14 13:56:38       42.99      Place Order
# 226905    527398  2018-03-14 13:57:25       42.99  Shopping Basket
# 226906    527399  2018-03-14 13:57:34      141.58  Shopping Basket
# 226907    527400  2018-03-14 13:57:41       19.98  Shopping Basket
# 226908    527401  2018-03-14 13:58:36       18.98      Place Order
#
# [226909 rows x 4 columns]

# %%
import pandas as pd
products_df4=pd.read_csv("/content/products.csv")
products_df4
# Out:
#            sku                                           name  \
# 0      RAI0007              Silver Rain Design mStand Support
# 1      APP0023              Apple Mac Keyboard Keypad Spanish
# 2      APP0025               Mighty Mouse Apple Mouse for Mac
# 3      APP0072  Apple Dock to USB Cable iPhone and iPod white
# 4      KIN0007    Mac Memory Kingston 2GB 667MHz DDR2 SO-DIMM
# ...        ...                                            ...
# 19321  BEL0376        Belkin Travel Support Apple Watch Black
# 19322  THU0060   Enroute Thule 14L Backpack MacBook 13 "Black
# 19323  THU0061    Enroute Thule 14L Backpack MacBook 13 "Blue
# 19324  THU0062     Enroute Thule 14L Backpack MacBook 13 "Red
# 19325  THU0063   Enroute Thule 14L Backpack MacBook 13 "Green
#
#                                                     desc  price promo_price  \
# 0           Aluminum support compatible with all MacBook  59.99     499.899
# ...

# %%
# Merge der Orderlines mit den Produktinformationen anhand 'sku'
merged_df = orderlines_df2.merge(products_df4, on='sku', how='left')

# %%
merged_df
# Out:
#              id  id_order  product_id  product_quantity      sku unit_price  \
# 0       1119109    299539           0                 1  OTT0133      18.99
# 1       1119110    299540           0                 1  LGE0043     399.00
# 2       1119111    299541           0                 1  PAR0071     474.05
# 3       1119112    299542           0                 1  WDT0315      68.39
# 4       1119113    299543           0                 1  JBL0104      23.74
# ...         ...       ...         ...               ...      ...        ...
# 379810  1650199    527398           0                 1  JBL0122      42.99
# 379811  1650200    527399           0                 1  PAC0653     141.58
# 379812  1650201    527400           0                 2  APP0698       9.99
# 379813  1650202    527388           0                 1  BEZ0204      19.99
# 379814  1650203    527401           0                 1  APP0927      13.99
#
#                        date  \
# ...

# %%
def categorize_description(desc):
    description = description.lower()
    if 'smartphone' in description:
        return 'Electronics'
    elif 'jacket' in description:
        return 'Clothing'
    elif 'chair' in description:
        return 'Furniture'
    else:
        return 'Other'

# %%
def categorize_description(description):
    description = description.lower()
    if 'smartphone' in description:
        return 'Electronics'
    elif 'jacket' in description:
        return 'Clothing'
    elif 'chair' in description:
        return 'Furniture'
    else:
        return 'Other'

merged_df['Category'] = merged_df['product_description'].apply(categorize_description)

# %%
orderlines_df2['sku'] = orderlines_df2['sku'].astype(str)
products_df4['sku'] = products_df4['sku'].astype(str)

# %%
print(merged_df.head())
# Out:
#         id  id_order  product_id  product_quantity      sku unit_price  \
# 0  1119109    299539           0                 1  OTT0133      18.99
# 1  1119110    299540           0                 1  LGE0043     399.00
# 2  1119111    299541           0                 1  PAR0071     474.05
# 3  1119112    299542           0                 1  WDT0315      68.39
# 4  1119113    299543           0                 1  JBL0104      23.74
#
#                   date                                               name  \
# 0  2017-01-01 00:07:19  Otterbox iPhone Case Symmetry 2.0 SE / 5s / 5 ...
# 1  2017-01-01 00:19:45         27UD58-B LG Monitor 27 "4K UHD DisplayPort
# 2  2017-01-01 00:20:57  Parrot Bebop 2 White + Command FLYPAD and FPV ...
# 3  2017-01-01 00:51:40              Blue WD 2TB Hard Drive 35 "Mac and PC
# 4  2017-01-01 01:06:38                      Gray Bluetooth Speaker JBL GO
#
#                                                 desc  price promo_price  \
# ...

# %%
orderlines_df['sku'] = orderlines_df['sku'].str.strip().str.lower()
products_df['sku'] = products_df['sku'].str.strip().str.lower()

# %%
print(orderlines_df['sku'].unique())
print(products_df['sku'].unique())
# Out:
# ['ott0133' 'lge0043' 'par0071' ... 'hte0013-a' 'adn0061' 'rep0299']
# ['rai0007' 'app0023' 'app0025' ... 'thu0061' 'thu0062' 'thu0063']
